# %%
import pandas as pd

# %%
df = pd.read_csv("Mumbai House Prices.csv")

# %%
df.head()
# Out:
#    bhk       type                              locality  area  price  \
# 0    3  Apartment   Lak And Hanware The Residency Tower   685   2.50
# 1    2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2    2  Apartment                         Romell Serene   610   1.73
# 3    2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4    2  Apartment                         Origin Oriana   659  94.11
#
#   price_unit          region              status  age
# 0         Cr    Andheri West       Ready to move  New
# 1          L    Naigaon East  Under Construction  New
# 2         Cr   Borivali West  Under Construction  New
# 3          L          Panvel  Under Construction  New
# 4          L  Mira Road East  Under Construction  New

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76038 entries, 0 to 76037
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bhk         76038 non-null  int64
#  1   type        76038 non-null  object
#  2   locality    76038 non-null  object
#  3   area        76038 non-null  int64
#  4   price       76038 non-null  float64
#  5   price_unit  76038 non-null  object
#  6   region      76038 non-null  object
#  7   status      76038 non-null  object
#  8   age         76038 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 5.2+ MB

# %%
df.isnull().sum()
# Out:
# bhk           0
# type          0
# locality      0
# area          0
# price         0
# price_unit    0
# region        0
# status        0
# age           0
# dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# Apartment            74854
# Studio Apartment       882
# Villa                  226
# Independent House       73
# Penthouse                3
# Name: count, dtype: int64

# %%
df['type'] = df['type'].replace(['Independent House','Penthouse'],'other')

# %%
df = pd.get_dummies(df,columns=['type'],drop_first=True)

# %%
df.head()
# Out:
#    bhk                              locality  area  price price_unit  \
# 0    3   Lak And Hanware The Residency Tower   685   2.50         Cr
# 1    2     Radheya Sai Enclave Building No 2   640  52.51          L
# 2    2                         Romell Serene   610   1.73         Cr
# 3    2  Soundlines Codename Urban Rainforest   876  59.98          L
# 4    2                         Origin Oriana   659  94.11          L
#
#            region              status  age  type_Studio Apartment  type_Villa  \
# 0    Andheri West       Ready to move  New                  False       False
# 1    Naigaon East  Under Construction  New                  False       False
# 2   Borivali West  Under Construction  New                  False       False
# 3          Panvel  Under Construction  New                  False       False
# 4  Mira Road East  Under Construction  New                  False       False
#
#    type_other
# 0       False
# 1       False
# 2       False
# 3       False
# ...

# %%
df['locality'].value_counts()
# Out:
# locality
# Hiranandani Meadows         861
# Sheth Avalon                516
# T Bhimjyani The Verraton    499
# ACME Ozone Phase 2          467
# Runwal Gardens              389
#                            ...
# Cosmos Angel Tower            1
# Sheth Konark Empress          1
# Shree Chamunda Garden         1
# Vega Platinum Enclave         1
# Omkar Puram                   1
# Name: count, Length: 9782, dtype: int64

# %%
top_localities = df['locality'].value_counts().nlargest(20).index
df['locality'] = df['locality'].where(df['locality'].isin(top_localities),'other')

# %%
df = pd.get_dummies(df,columns=['locality'],drop_first=True)

# %%
df['area'].value_counts()
# Out:
# area
# 650     1662
# 1050    1381
# 1100    1151
# 1650    1041
# 750      950
#         ...
# 2875       1
# 1987       1
# 1749       1
# 2793       1
# 2772       1
# Name: count, Length: 2331, dtype: int64

# %%
df['area'].describe()
# Out:
# count    76038.000000
# mean      1024.536850
# std        670.276165
# min        127.000000
# 25%        640.000000
# 50%        872.000000
# 75%       1179.000000
# max      16000.000000
# Name: area, dtype: float64

# %%
df['price'].value_counts()
# Out:
# price
# 1.75     972
# 1.25     948
# 1.35     854
# 1.15     846
# 1.10     839
#         ...
# 45.08      1
# 60.36      1
# 58.32      1
# 48.02      1
# 60.55      1
# Name: count, Length: 4729, dtype: int64

# %%
df['price'] = df.apply(lambda x:x['price']*100 if x['price_unit'] == 'Cr'else x['price'],axis=1)

# %%
df.head()
# Out:
#    bhk  area   price price_unit          region              status  age  \
# 0    3   685  250.00         Cr    Andheri West       Ready to move  New
# 1    2   640   52.51          L    Naigaon East  Under Construction  New
# 2    2   610  173.00         Cr   Borivali West  Under Construction  New
# 3    2   876   59.98          L          Panvel  Under Construction  New
# 4    2   659   94.11          L  Mira Road East  Under Construction  New
#
#    type_Studio Apartment  type_Villa  type_other  ...  locality_Raj Akshay  \
# 0                  False       False       False  ...                False
# 1                  False       False       False  ...                False
# 2                  False       False       False  ...                False
# 3                  False       False       False  ...                False
# 4                  False       False       False  ...                False
#
#    locality_Reputed Builder Wild Wood Park 2  locality_Runwal Bliss  \
# ...

# %%
df.drop(columns='price_unit',inplace=True)

# %%
df.head()
# Out:
#    bhk  area   price          region              status  age  \
# 0    3   685  250.00    Andheri West       Ready to move  New
# 1    2   640   52.51    Naigaon East  Under Construction  New
# 2    2   610  173.00   Borivali West  Under Construction  New
# 3    2   876   59.98          Panvel  Under Construction  New
# 4    2   659   94.11  Mira Road East  Under Construction  New
#
#    type_Studio Apartment  type_Villa  type_other  \
# 0                  False       False       False
# 1                  False       False       False
# 2                  False       False       False
# 3                  False       False       False
# 4                  False       False       False
#
#    locality_Amar Vinay Heritage  ...  locality_Raj Akshay  \
# 0                         False  ...                False
# 1                         False  ...                False
# 2                         False  ...                False
# ...

# %%
df['region'].value_counts()
# Out:
# region
# Thane West             14868
# Mira Road East          9902
# Dombivali               3041
# Kandivali East          2568
# Kharghar                2362
#                        ...
# Adaigaon                   1
# Sector-4 New Panvel        1
# Versova                    1
# Sector 6 Kamothe           1
# Pen                        1
# Name: count, Length: 228, dtype: int64

# %%
top_region = df['region'].value_counts().nlargest(20).index
df['region'] = df['region'].where(df['region'].isin(top_region),'other')

# %%
df = pd.get_dummies(df,columns=['region'],drop_first=True)

# %%
df.head()
# Out:
#    bhk  area   price              status  age  type_Studio Apartment  \
# 0    3   685  250.00       Ready to move  New                  False
# 1    2   640   52.51  Under Construction  New                  False
# 2    2   610  173.00  Under Construction  New                  False
# 3    2   876   59.98  Under Construction  New                  False
# 4    2   659   94.11  Under Construction  New                  False
#
#    type_Villa  type_other  locality_Amar Vinay Heritage  \
# 0       False       False                         False
# 1       False       False                         False
# 2       False       False                         False
# 3       False       False                         False
# 4       False       False                         False
#
#    locality_Cosmos Horizon  ...  region_Malad West  region_Mira Road East  \
# 0                    False  ...              False                  False
# ...

# %%
df['status'].value_counts()
# Out:
# status
# Ready to move         44982
# Under Construction    31056
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['status'] = le.fit_transform(df['status'])

# %%
df.head()
# Out:
#    bhk  area   price  status  age  type_Studio Apartment  type_Villa  \
# 0    3   685  250.00       0  New                  False       False
# 1    2   640   52.51       1  New                  False       False
# 2    2   610  173.00       1  New                  False       False
# 3    2   876   59.98       1  New                  False       False
# 4    2   659   94.11       1  New                  False       False
#
#    type_other  locality_Amar Vinay Heritage  locality_Cosmos Horizon  ...  \
# 0       False                         False                    False  ...
# 1       False                         False                    False  ...
# 2       False                         False                    False  ...
# 3       False                         False                    False  ...
# 4       False                         False                    False  ...
#
#    region_Malad West  region_Mira Road East  region_Mulund West  \
# ...

# %%
df['age'].value_counts()
# Out:
# age
# New        38072
# Resale     23357
# Unknown    14609
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df,columns=['age'],drop_first=True)

# %%
df.head()
# Out:
#    bhk  area   price  status  type_Studio Apartment  type_Villa  type_other  \
# 0    3   685  250.00       0                  False       False       False
# 1    2   640   52.51       1                  False       False       False
# 2    2   610  173.00       1                  False       False       False
# 3    2   876   59.98       1                  False       False       False
# 4    2   659   94.11       1                  False       False       False
#
#    locality_Amar Vinay Heritage  locality_Cosmos Horizon  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
#
#    locality_Hiranandani Estate  ...  region_Mulund West  region_Panvel  \
# 0                        False  ...               False          False
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['area'] = scaler.fit_transform(df[['area']])

# %%
df.head()
# Out:
#    bhk      area   price  status  type_Studio Apartment  type_Villa  \
# 0    3  0.035154  250.00       0                  False       False
# 1    2  0.032319   52.51       1                  False       False
# 2    2  0.030429  173.00       1                  False       False
# 3    2  0.047187   59.98       1                  False       False
# 4    2  0.033516   94.11       1                  False       False
#
#    type_other  locality_Amar Vinay Heritage  locality_Cosmos Horizon  \
# 0       False                         False                    False
# 1       False                         False                    False
# 2       False                         False                    False
# 3       False                         False                    False
# 4       False                         False                    False
#
#    locality_Hiranandani Estate  ...  region_Mulund West  region_Panvel  \
# ...

# %%
df.to_csv("cleaned_data.csv",index=None)
